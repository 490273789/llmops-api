# %% [markdown]
# 字典操作

# %%
a = {"b": True, "c": 1}
# a["b"] = False
# a.update({"b": False})
a.from_mapping({"b": False})

print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 a = {"b": True, "c": 1}
#       2 # a["b"] = False
#       3 # a.update({"b": False})
# ----> 4 a.from_mapping({"b": False})
#       6 print(a)
#
# AttributeError: 'dict' object has no attribute 'from_mapping'
